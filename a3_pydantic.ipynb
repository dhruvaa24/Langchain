# %%
from pydantic import BaseModel, Field

# %%
class user(BaseModel):
    id: int = Field(gt=0, description="unique user id")
    name: str = Field(min_length=3, max_length=50, description="user name")
    age: int = Field(ge=1, le=100, description="user age")
    is_active: bool = Field(default=True, description="user active status")

# %%
user1 = user(id=1, name="John", age=25)
print(user1)
# Out:
# id=1 name='John' age=25 is_active=True
