# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
from langchain.agents import create_agent
from langchain.tools import tool
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI
from tavily import TavilyClient
tavily = TavilyClient()

# %%
@tool
def search(query: str) -> str:
    """Tool to search the web
    Args:
        query: The query to search for
    Returns:
        The first result from the search
    """
    print(f"Searching for {query}")
    return tavily.search(query=query)

# %%
llm = ChatOpenAI(model="openai/gpt-4o-mini")
tools = [search]
agent = create_agent(llm, tools)
agent.invoke({"messages":  HumanMessage(content="What is the weather in Tokyo?")})
# Out:
# Searching for Tokyo weather
# {'messages': [HumanMessage(content='What is the weather in Tokyo?', additional_kwargs={}, response_metadata={}, id='f722f515-595f-4053-b62b-f6632416d3d7'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 70, 'total_tokens': 84, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1590f93f9d', 'id': 'chatcmpl-D560cjpmd6W8Uin4Hu0GFjidhrQkD', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c229a-ff82-7280-854d-6db723ef3101-0', tool_calls=[{'name': 'search', 'args': {'query': 'Tokyo weather'}, 'id': 'call_JlC6Z5zKs2Td7xq7OBQCHdLj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 70, 'output_tokens': 14, 'total_tokens': 84, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"query": "Tokyo weather", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Tokyo, Japan", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Tokyo\', \'region\': \'Tokyo\', \'country\': \'Japan\', \'lat\': 35.6895, \'lon\': 139.6917, \'tz_id\': \'Asia/Tokyo\', \'localtime_epoch\': 1770107114, \'localtime\': \'2026-02-03 17:25\'}, \'current\': {\'last_updated_epoch\': 1770106500, \'last_updated\': \'2026-02-03 17:15\', \'temp_c\': 9.0, \'temp_f\': 48.2, \'is_day\': 0, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.5, \'wind_kph\': 7.2, \'wind_degree\': 47, \'wind_dir\': \'NE\', \'pressure_mb\': 1021.0, \'pressure_in\': 30.15, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 27, \'cloud\': 25, \'feelslike_c\': 8.0, \'feelslike_f\': 46.4, \'windchill_c\': 8.2, \'windchill_f\': 46.8, \'heatindex_c\': 9.2, \'heatindex_f\': 48.5, \'dewpoint_c\': -11.1, \'dewpoint_f\': 12.0, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 0.0, \'gust_mph\': 6.1, \'gust_kph\': 9.8}}", "score": 0.9941134, "raw_content": null}, {"url": "https://world-weather.info/forecast/japan/tokyo/february-2026/", "title": "Weather in Tokyo in February 2026 (Tōkyō-to)", "content": "Weather in Tokyo in February 2026. Tokyo Weather Forecast for February 2026 ... Tuesday, 3 February. Day. +50°. 11.6. 30. 32%. +39°. 06:39 AM. 05:09 PM. Waning", "score": 0.95186776, "raw_content": null}, {"url": "https://www.facebook.com/meteobox.tokyo/photos/tokyo-monday-02022026-weather-forecast-for-edo-feb-3-2026during-the-day-clear-th/1511565964306281/", "title": "Tokyo - Japan weather forecast - Facebook", "content": "Tokyo, Monday 02/02/2026: Weather forecast for Edo Feb. 3, 2026During the day clear. The highest temperature 9 °C .", "score": 0.93265617, "raw_content": null}, {"url": "https://www.weather25.com/asia/japan/tokyo?page=month&month=February", "title": "Tokyo weather in February 2026 - Weather25.com", "content": "Location was added to My Locations. Location was removed from My Locations. # Tokyo weather in February 2026. | 1  8° /3° | 2  8° /1° | 3  10° /5° | 4  9° /4° | 5  9° /4° | 6  8° /3° | 7  9° /4° |. | 8  9° /4° | 9  9° /3° | 10  7° /4° | 11  11° /4° | 12  12° /5° | 13  13° /7° | 14  11° /5° |. | 15  12° /6° | 16  13° /6° | 17  11° /5° | 18  10° /5° | 19  12° /6° | 20  12° /7° | 21  12° /6° |. | 22  12° /6° | 23  11° /5° | 24  10° /4° | 25  12° /5° | 26  12° /6° | 27  12° /5° | 28  13° /6° |. | March | **13°** / 6° | 8 | 22 | 1 | 192 mm | Bad | Tokyo in March |. Rain in Tokyo in February.", "score": 0.8974172, "raw_content": null}, {"url": "https://www.japanhighlights.com/japan/weather-in-february", "title": "Japan Weather in February 2026", "content": "Tokyo remains dry and sunny in February, with a high temperature averaging 11°C (52°F). Winter illuminations make Tokyo a romantic city, especially for", "score": 0.88564163, "raw_content": null}], "response_time": 1.61, "request_id": "a9529190-0635-4fb1-97a5-d434896e08bf"}', name='search', id='6088108a-d7de-4ffb-81fa-0958100a3d70', tool_call_id='call_JlC6Z5zKs2Td7xq7OBQCHdLj'),
#   AIMessage(content='The current weather in Tokyo is as follows:\n\n- **Temperature:** 9°C (48.2°F)\n- **Condition:** Sunny\n- **Wind Speed:** 4.5 mph (7.2 kph) from the NE\n- **Humidity:** 27%\n- **Pressure:** 1021 mb\n- **Visibility:** 10 km\n\nFor more details, you can check the [Weather API](https://www.weatherapi.com/).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 1311, 'total_tokens': 1405, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1590f93f9d', 'id': 'chatcmpl-D560gZePVBbwLHUUq8AdOkbUUPYHc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c229b-111d-7570-a81a-202ad009443e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1311, 'output_tokens': 94, 'total_tokens': 1405, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
