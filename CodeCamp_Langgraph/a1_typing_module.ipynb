# %%
from typing import TypedDict, List
#TypedDict lets you define the expected “shape” of a dictionary using types.
class State(TypedDict):
    messages: List[str]
    step: int

# %%
from typing import Union
def sq(x: Union[int, float]) -> Union[int, float]:
    return x * x

def cube(x: Union[int, float]) -> Union[int, float]:
    return x * x * x

x=5
sq(x)
x=5.23
sq(x)

#union means : “This variable can be one of multiple types.”
# Out:
# 27.352900000000005

# %%
from typing import Optional
name: Optional[str] #can be str or None

# %%
from typing import Any

def print_value(x : Any): #x can be any data structure
    print(x)

# %%
sq = lambda x  :x* x ; 
sq(10)

nums = [1,2,3,4,5]

squared_nums = list(map(lambda x : x*x , nums)) # run for every element in nums

squared_nums
# Out:
# [1, 4, 9, 16, 25]
